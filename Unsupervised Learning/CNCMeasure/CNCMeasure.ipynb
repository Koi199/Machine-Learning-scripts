# %% [markdown]
# **Final Exam Submission**

# %% [markdown]
# # 1. Imports and Dependencies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 2. Data Loading and Preprocessing
# ## 2.1 Data Loading

# %%
df = pd.read_csv('CNCMeasureData.csv')

# %% [markdown]
# ## 2.2 Exploratory Data Analysis

# %%
df
# Out:
#       Dimension 1 (mm)  Dimension 2 (mm)
# 0               100.82            101.33
# 1               100.29            101.30
# 2                98.10             99.99
# 3               100.42            101.03
# 4                97.24             99.84
# ...                ...               ...
# 1245            102.94             99.82
# 1246            101.78            102.37
# 1247            103.01            101.10
# 1248            104.63            101.77
# 1249            103.59            100.24
#
# [1250 rows x 2 columns]

# %% [markdown]
# ## 2.3 Data Preprocessing

# %%
plt.plot(df['Dimension 1 (mm)'], df['Dimension 2 (mm)'], marker ='o', linestyle = 'none')
plt.xlabel('Dimension 1 (mm)')
plt.ylabel('Dimension 2 (mm)')
plt.grid()
plt.show()

# %% [markdown]
# ## 2.4 Separate input and output and split dataset

# %%
#Split data into feature and target
X = df.iloc[:,[0,1]].values

X
# Out:
# array([[100.82, 101.33],
#        [100.29, 101.3 ],
#        [ 98.1 ,  99.99],
#        ...,
#        [103.01, 101.1 ],
#        [104.63, 101.77],
#        [103.59, 100.24]])

# %% [markdown]
# ## 2.5 Scaling

# %% [markdown]
# # 3. Model Development

# %%
from sklearn.mixture import GaussianMixture

# Fit Gaussian Mixture Model
gmm = GaussianMixture(n_components=3, covariance_type='full', random_state=42)  # 4 clusters
gmm.fit(X)
labels = gmm.predict(X)

# Plot the GMM clusters
plt.figure(figsize=(8, 6))
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', s=50, alpha=0.6)
plt.scatter(gmm.means_[:, 0], gmm.means_[:, 1], c='red', marker='x', s=100, label='Centroids')
plt.title('CNC Measurements')
plt.xlabel('Dimension 1 (mm)')
plt.ylabel('Dimension 2 (mm)')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # 4. Model Evaluation
# ## 4.1 Performance Metrics

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, r2_score

# %% [markdown]
# ## 4.2 Results Visualization

# %% [markdown]
# # 5. Conclusion
